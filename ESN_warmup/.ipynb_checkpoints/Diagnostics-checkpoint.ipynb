# %%
import numpy as np
from matplotlib import pyplot as plt

def load(name):
    return np.load("./model/" + name + ".npy")

history = load("history")
trainable = load("trainable")
wState = load("stateWeights")
wInput = load("input")
bias = load("bias")
yhats = load("predictions")
ys = load("labels")

# %%
figs, ax = plt.subplots(2, 2, figsize=(12, 8))

s = 300
e = s + 80
size = e - s

indicies = [32, 13, 12, 82]
interest = history[s:e]
interest = np.resize(interest, (100, size))

xs = np.arange(s, e)
py = ys[s:e]
phats = yhats[s:e]


for i in indicies:
    ax[0, 0].plot(xs, interest[i])
    
ax[0, 1].plot(xs, py)
ax[1, 0].plot(xs, phats)
# Out:
# Mean abs size trainable
# 1.8691884133856669
# Max weight (abs)
# 8.128136574573904
#
# Mean abs size input
# 0.24898031952043087
#
# Mean abs size state
# 0.08002913040962943
# Spectral radius of state
# 1.0109693185081305

# %%
print("Mean abs size trainable")
print(np.sum(np.abs(trainable)) / trainable.size)
print("Max weight (abs)")
print(np.max(np.abs(trainable)))
print()

print("Mean abs size input")
print(np.sum(np.abs(wInput)) / wInput.size)
print()

print("Mean abs size state")
print(np.sum(np.abs(wState)) / wState.size)
print("Spectral radius of state")
eigens = np.resize(np.linalg.eigvals(wState), (10000, 1))
print(np.linalg.norm(np.max(eigens)))

# %%
figs, ax = plt.subplots(2, 2, figsize=(12, 8))

s = 300
e = s + 80
size = e - s

indicies = [32, 13, 12, 82]
interest = history[s:e]
interest = np.resize(interest, (100, size))

xs = np.arange(s, e)
py = ys[s:e]
phats = yhats[s:e]


for i in indicies:
    ax[0, 0].plot(xs, interest[i])
    
ax[0, 1].plot(xs, py)
ax[1, 0].plot(xs, phats)
# Out:
# array([ -4.77856662,  -6.32550061,  -0.62225775,   0.44113022,
#        -12.53309009,  -2.5440996 ,  -0.82617434,   0.22721041,
#          2.97891457,  -3.08604465,   3.22437277,   2.98518968,
#         -4.35918443,  -2.17289394,   5.52911241,  -7.46002135,
#          8.58438393,  -0.52567371,   6.1065626 ,  -0.65519752,
#          0.28183046,  -2.61843941,   7.55880911,  -1.58374236,
#         -4.5193568 ,   0.97580665,  -1.19619628,   0.9307062 ,
#          2.85237134,  -2.22385942,  -4.50003027,  -2.95464094,
#          0.5332895 ,   1.14263647,   0.39035995,  -3.87187921,
#         -9.28355865,   4.28397741,  -1.92186461,   0.81542573,
#          0.16971991,  -0.83386606,  -2.30742394,  -6.32413312,
#         -3.34736649,   2.02383135,  -0.40152062,   2.36628702,
#          7.60052041,   0.893385  ,  -6.8855721 ,  -1.72678803,
#         -1.9286425 ,  -3.55196377,  -1.74700089,   3.22355698,
#         -2.86977199,   0.19881272,  -7.60721506,   0.75635758,
#         -3.08542077,  -0.51622656,  -2.26243075,   4.13247597,
#         -1.6757475 ,  -0.69665052,   1.03364654,  -0.42863205,
#          0.37000704,   5.10277937,  10.41750285,  -1.11209041,
#          2.54522415,  -1.5443083 ,   4.60793182,   2.77711533,
#         -0.02860836,   2.69808521,  13.78527425,   2.86126654,
#          0.26231267,   3.08098295,  -7.45084404,  -6.94809182,
#         -4.7229538 ,   6.43327542,   5.42021563,   3.31559024,
#          5.27115789,   0.73100165,   5.44962196,   2.83743861,
#         -7.27731718,  -2.50231216,  -3.22641992,  -2.50570823,
#         -1.53712432,  -2.79341197,   4.89874429,  -4.64227897])

# %%
l = np.array([2, 3, 123])
t = np.array([3, 5, 8])

np.sum(l * t) == t.dot(l)
# Out:
# True

# %%
h = np.array([
    [1, 2, 3],
    [1, 4, 3],
    [9, 2, 3],
    [1, 2, 7],
    [0, 9, 7]
])

t = np.array([1, 4, 8])

print(h * t)
np.dot(h, t)
# Out:
# [[ 1  8 24]
#  [ 1 16 24]
#  [ 9  8 24]
#  [ 1  8 56]
#  [ 0 36 56]]
# array([33, 41, 41, 65, 92])

# %%
np.linalg.eigvals(wState)
# Out:
# array([-91.24482644 +0.j        , -18.43256953 +0.j        ,
#         -0.32895191+18.95444863j,  -0.32895191-18.95444863j,
#         10.38073607+15.48230592j,  10.38073607-15.48230592j,
#         -4.04200371+17.54989533j,  -4.04200371-17.54989533j,
#         16.20643574 +7.6506885j ,  16.20643574 -7.6506885j ,
#        -10.44083712+13.21017883j, -10.44083712-13.21017883j,
#        -16.8789336  +1.08917303j, -16.8789336  -1.08917303j,
#         11.2875714 +12.07186556j,  11.2875714 -12.07186556j,
#        -12.22948135+10.83152135j, -12.22948135-10.83152135j,
#        -14.6468627  +6.31838681j, -14.6468627  -6.31838681j,
#         15.29318015 +4.27324033j,  15.29318015 -4.27324033j,
#         -5.04244553+14.6483101j ,  -5.04244553-14.6483101j ,
#         14.75100994 +0.j        ,   9.79431124+11.53364299j,
#          9.79431124-11.53364299j,  -1.64913463+15.01475796j,
#         -1.64913463-15.01475796j, -11.24035334 +9.12230868j,
#        -11.24035334 -9.12230868j,   0.57279031+14.46410054j,
#          0.57279031-14.46410054j,  14.29435935 +0.j        ,
#        -13.90922213 +0.84514178j, -13.90922213 -0.84514178j,
#          2.70205936+13.73415739j,   2.70205936-13.73415739j,
#         -7.26627592+11.13474858j,  -7.26627592-11.13474858j,
#         13.09319676 +3.70693278j,  13.09319676 -3.70693278j,
#        -12.42162827 +4.74967707j, -12.42162827 -4.74967707j,
#          6.25138986+11.8999402j ,   6.25138986-11.8999402j ,
#          4.91048829+12.09342026j,   4.91048829-12.09342026j,
#         -0.42194265+12.45717253j,  -0.42194265-12.45717253j,
#         -7.56220386 +9.09727233j,  -7.56220386 -9.09727233j,
#         11.74418994 +3.3732244j ,  11.74418994 -3.3732244j ,
#         -6.42702148 +9.25737078j,  -6.42702148 -9.25737078j,
#         -2.79455152+10.65970816j,  -2.79455152-10.65970816j,
#          6.06085163 +9.66230383j,   6.06085163 -9.66230383j,
#        -10.24576815 +3.20939368j, -10.24576815 -3.20939368j,
#          9.31000079 +5.82967328j,   9.31000079 -5.82967328j,
#          2.2265066 +10.51301308j,   2.2265066 -10.51301308j,
#        -10.17403107 +2.42001334j, -10.17403107 -2.42001334j,
#          9.68122263 +2.40031247j,   9.68122263 -2.40031247j,
#         -8.27682121 +4.58233765j,  -8.27682121 -4.58233765j,
#          5.63409004 +7.09688319j,   5.63409004 -7.09688319j,
#          3.82819821 +7.81986547j,   3.82819821 -7.81986547j,
#         -6.01171267 +4.64222088j,  -6.01171267 -4.64222088j,
#          7.62730414 +3.17959876j,   7.62730414 -3.17959876j,
#          7.13065485 +0.j        ,   7.05552195 +4.01153316j,
#          7.05552195 -4.01153316j,  -7.73756603 +0.74519883j,
#         -7.73756603 -0.74519883j,  -0.41859675 +6.61933292j,
#         -0.41859675 -6.61933292j,  -1.86476753 +5.59562031j,
#         -1.86476753 -5.59562031j,  -6.05172449 +0.j        ,
#         -5.75035092 +0.j        ,   0.41915202 +4.70055933j,
#          0.41915202 -4.70055933j,   2.09225871 +5.03317319j,
#          2.09225871 -5.03317319j,  -1.58174272 +0.j        ,
#          2.29053387 +3.55477771j,   2.29053387 -3.55477771j,
#          4.02720688 +0.77222606j,   4.02720688 -0.77222606j])

# %%
def estimate_time(scales, multi=False):
    runs = scales.size ** 2
    return (runs * 1.5 if multi else 15) / 3600

estimate_time(np.arange(0.01, 1, 0.015), multi=True)
# Out:
# 1.815

# %%
import multiprocessing

multiprocessing.cpu_count()
# Out:
# 8

# %%
np.arange(0.1, 0.8, 0.4).size
# Out:
# 2

# %%
n = 50
epochs = 120
def get_square_size(x):
    b = n // 2
    a = (1 - b) / epochs
    return a * x + b

get_square_size(11)
# Out:
# 22.8
